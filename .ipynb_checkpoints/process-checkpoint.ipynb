# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('process-data-v2.csv',nrows=1000)

data
# Out:
#      cpuUtilization(%)       processName  processID  memoryUtilization(%)  \
# 0                 0.02             CAPSM       1780                  1.05
# 1                 0.00           conhost       5968                  0.00
# 2                 0.01             csrss        540                  0.00
# 3                 0.15  DCProcessMonitor       5084                  0.43
# 4                 0.00               dwm        412                  0.00
# ..                 ...               ...        ...                   ...
# 995               0.00           wininit        608                  0.00
# 996               0.01          WmiApSrv        520                  0.00
# 997               0.00        dcondemand      10612                  0.60
# 998               0.00          macmnsvc       1264                  0.00
# 999               0.17          mcshield       6240                  0.00
#
#        ciName              lastPolledAt
# 0    awnck006  2023-09-12T08:30:24.000Z
# 1    awnck006  2023-09-12T08:30:24.000Z
# 2    awnck006  2023-09-12T08:30:24.000Z
# 3    awnck006  2023-09-12T08:30:24.000Z
# 4    awnck006  2023-09-12T08:30:24.000Z
# ..        ...                       ...
# 995  awnck006  2023-09-12T10:10:19.000Z
# 996  awnck006  2023-09-12T10:10:19.000Z
# 997  awnck006  2023-09-12T10:10:19.000Z
# 998  awnck006  2023-09-12T10:10:19.000Z
# 999  awnck006  2023-09-12T10:10:19.000Z
#
# [1000 rows x 6 columns]

# %%
data.describe()
# Out:
#        cpuUtilization(%)   processID  memoryUtilization(%)
# count       10000.000000  10000.0000          10000.000000
# mean            0.483623   4173.2036              0.426896
# std             3.051748   3498.2479              0.628301
# min             0.000000      0.0000              0.000000
# 25%             0.000000    961.0000              0.000000
# 50%             0.010000   3000.0000              0.180000
# 75%             0.050000   6396.0000              0.610000
# max            51.940000  12284.0000              3.090000

# %%
#Line Plot
data['lastPolledAt']=pd.to_datetime(data['lastPolledAt'])
plt.figure(figsize=(10,5))
plt.plot(data['lastPolledAt'],data['cpuUtilization(%)'])
plt.title('CPU Utilization over time')
plt.xlabel('Timestamp')
plt.ylabel('CPU Utilization')
plt.xticks(rotation=45)
plt.show()

# %%
#Bar plot
plt.figure(figsize=(10,5))
average_memory = data.groupby('processName')['memoryUtilization(%)'].mean()
average_memory.plot(kind='bar')
plt.title('Average Memory Utilization by Process Name')
plt.xlabel('Process Name')
plt.ylabel('Average Memory Utilization')
plt.show()

# %%
#Histogram
plt.figure(figsize=(10,5))
plt.hist(data['cpuUtilization(%)'],bins=20, color='yellow')
plt.title('Distribution of CPU Utiliation')
plt.xlabel('Process Name')
plt.ylabel('Frequency')
plt.show()

# %%
max_cpu_process = data[data['cpuUtilization(%)']==data['cpuUtilization(%)'].max()]['processName'].values[0]
max_cpu_process
# Out:
# 'SWJobEngineWorker2'

# %%
process_name_counts = data['processName'].value_counts()
most_frequent_process = process_name_counts.idxmax()
most_frequent_process
# Out:
# 'csrss'

# %%
#Scatter Plot
plt.figure(figsize=(10,5))
plt.scatter(data['cpuUtilization(%)'], data['memoryUtilization(%)'])
plt.title('CPU Utilization vs Memory Utilization')
plt.xlabel('CPU Utilization')
plt.ylabel('Memory Utilization')
plt.show()

# %%
#Correlation between CPU vs Memory Utilization
correlation = data['cpuUtilization(%)'].corr(data['memoryUtilization(%)'])

correlation
# Out:
# 0.4408083314453604

# %%
#maximum cpu utilized my which ci
avg_cpu_by_ci = data.groupby('ciName')['cpuUtilization(%)'].mean()
max_avg_cpu_ci = avg_cpu_by_ci.idxmax()
max_avg_cpu_ci
# Out:
# 'awnck006'

# %%
#aggregation by processName
process_stats = data.groupby('processName')[['memoryUtilization(%)', 'cpuUtilization(%)']].mean()
process_stats
# Out:
#                                       memoryUtilization(%)  cpuUtilization(%)
# processName
# CAPSM                                             1.027143           0.020000
# DCProcessMonitor                                  0.430000           0.150000
# Idle                                              0.000000           0.000000
# LogonUI                                           0.000000           0.020000
# MVArmorService32                                  0.784762           0.054762
# MVArmorService64                                  0.000000           0.000000
# MinervaMcAfeePropertyRequestListener              0.220000           0.000000
# NetWrixRemotingHost64                             1.102381           0.010000
# Netwrix.WSA.AgentService                          1.209048           0.030000
# SWJobEngineSvc2                                   1.288571           0.960000
# SWJobEngineWorker2                                2.745500          15.558000
# SWJobEngineWorker2x64                             1.383500           0.017500
# SolarWinds.Agent.Discovery.Plugin                 0.280000           0.280000
# SolarWinds.Agent.Service                          0.498571           0.020000
# SolarWinds.ServiceHost.Process                    0.970476           0.010000
# System                                            0.000000           0.110000
# WmiApSrv                                          0.000000           0.056875
# WmiPrvSE                                          0.785238           0.757619
# amazon-cloudwatch-agent                           1.276190           0.027143
# amazon-ssm-agent                                  0.480952           0.010000
# conhost                                           0.000000           0.180000
# csrss                                             0.000000           0.005238
# dcagentservice                                    0.394762           0.000000
# dcconfig                                          0.610000           0.635000
# dcondemand                                        0.600000           0.000000
# dwm                                               0.000000           0.000000
# ir_agent                                          0.798571           0.082857
# lsass                                             0.000000           0.190000
# macmnsvc                                          0.000000           0.000000
# macompatsvc                                       0.399524           0.010000
# masvc                                             0.000000           0.050000
# mcshield                                          0.000000           0.170000
# mfeesp                                            0.000000           0.020000
# mfefw                                             0.000000           0.010000
# mfehcs                                            0.180000           0.000000
# mfemactl                                          0.316500           0.010000
# mfemms                                            0.309524           0.000000
# mfetp                                             0.000000           0.280000
# mfevtps                                           0.335714           0.020000
# msdtc                                             0.000000           0.000000
# rapid7_endpoint_broker                            0.871000           0.000000
# services                                          0.000000           0.060000
# smss                                              0.000000           0.000000
# sqlservr                                          0.000000           0.855238
# sqlwriter                                         0.320000           0.000000
# ssm-agent-worker                                  0.670000           0.020000
# start-amazon-cloudwatch-agent                     0.130000           0.000000
# svchost                                           0.000000           0.010000
# wininit                                           0.000000           0.000000
# winlogon                                          0.000000           0.000000

# %%
#Time Series Analysis
from statsmodels.tsa.seasonal import seasonal_decompose

data['lastPolledAt']=pd.to_datetime(data['lastPolledAt'])
data.set_index('lastPolledAt',inplace=True)
result = seasonal_decompose(data['cpuUtilization(%)'],model='additive')

plt.figure(figsize=(12,8))
plt.subplot(4,1,1)
plt.plot(data['cpuUtilization(%)'],label='Original')
plt.legend(loc='upper left')
plt.title('Original Data')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18896\644575916.py in ?()
#       1 #Time Series Analysis
#       2 from statsmodels.tsa.seasonal import seasonal_decompose
#       3
# ----> 4 data.set_index('lastPolledAt',inplace=True)
#       5 result = seasonal_decompose(data['cpuUtilization(%)'],model='additive')
#       6
#       7 plt.figure(figsize=(12,8))
#
# ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5855                     if not found:
#    5856                         missing.append(col)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#    5862             frame = self
#
# KeyError: "None of ['lastPolledAt'] are in the columns"
